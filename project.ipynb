# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/Users/lsm50/Top100.csv')
df
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# ...

# %%
df=pd.read_csv('/Users/lsm50/Top100.csv')
df
subset = df[['year','top genre','title','artist']]
print(subset)
# Out:
#     year                  top genre                                title  \
# 0   2020  canadian contemporary r&b                      Blinding Lights
# 1   2019                        pop                     Watermelon Sugar
# 2   2021                   cali rap               Mood (feat. iann dior)
# 3   2019                        pop                    Someone You Loved
# 4   2017                        pop                              Perfect
# ..   ...                        ...                                  ...
# 95  2016           canadian hip hop                            One Dance
# 96  2015                        pop                                Sugar
# 97  2021                  pop dance                             Emotions
# 98  2018                  dance pop                           Cold Water
# 99  2016                  dance pop  I Took A Pill In Ibiza - Seeb Remix
#
#            artist
# 0      The Weeknd
# 1    Harry Styles
# 2        24kGoldn
# ...

# %%
print(df.groupby('year')['top genre'].nunique())
# Out:
# year
# 1975     1
# 1995     1
# 2004     1
# 2008     1
# 2012     2
# 2013     3
# 2014     5
# 2015     6
# 2016     9
# 2017     8
# 2018    10
# 2019     9
# 2020     3
# 2021     3
# Name: top genre, dtype: int64

# %%
import matplotlib.pyplot as plt

year_top = df.groupby('year')['top genre'].nunique()
print(year_top)
# Out:
# year
# 1975     1
# 1995     1
# 2004     1
# 2008     1
# 2012     2
# 2013     3
# 2014     5
# 2015     6
# 2016     9
# 2017     8
# 2018    10
# 2019     9
# 2020     3
# 2021     3
# Name: top genre, dtype: int64

# %%
year_top.plot()
# Out:
# <AxesSubplot:xlabel='year'>
